# %%
import sympy
import numpy as np
import matplotlib.pyplot as plt

# gradient vector를 구하기 위해서 symbolic formula를 표현해줌
x, y = sympy.symbols('x,y')
#f=x**2+y**2+x*y
f=x**2+y**2+x*y - sympy.sin(x)*5

print(f)
# Out:
# x**2 + x*y + y**2 - 5*sin(x)

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.empty((10,10),float)
y=np.empty((10,10),float)

u=np.empty((10,10),float)
v=np.empty((10,10),float)



for i in range(10):
    for j in range(10):
        x[i][j]=i/10.0
        y[i][j]=i/10.0
        u[i][j]=i/10*2
        v[i][j]=i/10*2
        


plt.quiver(x,y,u,v,angles='xy',pivot='middle')
plt.ylim(0,1,1)
plt.xlim(0,1,1)
plt.grid('on')    
plt.show()

# %%
import pandas as pd

pd.read_excel('wafer.xlsx')
# Out:
#     die x  die y    scx     scy  dx  dy  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0      -1      4 -24000  132000   1   1         NaN           7           1
# 1       0      4      0  132000   1   1         NaN           8           2
# 2       1      4  24000  132000   1   1         NaN           5           6
# 3      -3      3 -72000   99000   1   1         NaN           1           4
# 4      -2      3 -48000   99000   1   1         NaN           7           4
# ..    ...    ...    ...     ...  ..  ..         ...         ...         ...
# 60      2     -3  48000  -99000   1   1         NaN           5           8
# 61      3     -3  72000  -99000   1   1         NaN           1           4
# 62     -1     -4 -24000 -132000   1   1         NaN           6           6
# 63      0     -4      0 -132000   1   1         NaN           6           9
# 64      1     -4  24000 -132000   1   1         NaN           2           5
#
#     Unnamed: 9  step pitch x    24000
# ...

# %%
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt

x=pd.read_excel('wafer.xlsx', usecols=[2])
y=pd.read_excel('wafer.xlsx', usecols=[3])
u=pd.read_excel('wafer.xlsx', usecols=[4])
v=pd.read_excel('wafer.xlsx', usecols=[5])


plt.quiver(x,y,u,v)
